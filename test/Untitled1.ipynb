# %%
import collections

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections

#test500-2.npy

# %%
data = np.load("base/test500-2.npy")
fig = plt.figure(figsize=(8, 8), dpi=1000)
ax = fig.add_subplot(111)
ax.set_xlim(-1.0, 1.0)
ax.set_ylim(-1.0, 1.0)
color = 'black'
alpha_max = 0.7
jsteps = 3

colormap = collections.defaultdict(lambda : 'black')
colormap.update({0:'black', 1:'blue', 2:'red', 3:'magenta'})
for i in range(data.shape[0]):
    if i not in [1]:
        continue
    color = colormap[i]
    color = 'maroon'
    for j in range(0, data.shape[2]-jsteps, jsteps):
        alpha = (j + 1)/data.shape[2]*alpha_max
        ax.plot(data[i, 0, j:j+jsteps+1], data[i, 1, j:j+jsteps+1], color=color, alpha=alpha)

tcircle = np.linspace(0, 2*np.pi, 101)
xcircle = np.cos(tcircle)*0.8
ycircle = np.sin(tcircle)*0.8
ax.plot(xcircle, ycircle, color='black')

# %%
data = np.load("base/test500-6.npy")
fig = plt.figure(figsize=(8, 8), dpi=1000)
ax = fig.add_subplot(111)
ax.set_xlim(-1.0, 1.0)
ax.set_ylim(-1.0, 1.0)
color = 'black'
alpha_max = 0.7
jsteps = 3

colormap = collections.defaultdict(lambda : 'black')
colormap.update({0:'black', 1:'blue', 2:'red', 3:'magenta'})
for i in range(data.shape[0]):
    if i not in [1]:
        continue
    color = colormap[i]
    color = 'midnightblue'
    for j in range(0, data.shape[2]-jsteps, jsteps):
        alpha = (j + 1)/data.shape[2]*alpha_max
        ax.plot(data[i, 0, j:j+jsteps+1], data[i, 1, j:j+jsteps+1], color=color, alpha=alpha)

tcircle = np.linspace(0, 2*np.pi, 101)
xcircle = np.cos(tcircle)*0.8
ycircle = np.sin(tcircle)*0.8
ax.plot(xcircle, ycircle, color='black')

# %%
data = np.load("base/test500-12.npy")
fig = plt.figure(figsize=(8, 8), dpi=1000)
ax = fig.add_subplot(111)
ax.set_xlim(-1.0, 1.0)
ax.set_ylim(-1.0, 1.0)
color = 'black'
alpha_max = 0.7
jsteps = 3

colormap = collections.defaultdict(lambda : 'black')
colormap.update({0:'black', 1:'blue', 2:'red', 3:'magenta'})
for i in range(data.shape[0]):
    if i not in [1]:
        continue
    color = colormap[i]
    color = 'darkmagenta'
    for j in range(0, data.shape[2]-jsteps, jsteps):
        alpha = (j + 1)/data.shape[2]*alpha_max
        ax.plot(data[i, 0, j:j+jsteps+1], data[i, 1, j:j+jsteps+1], color=color, alpha=alpha)

tcircle = np.linspace(0, 2*np.pi, 101)
xcircle = np.cos(tcircle)*0.8
ycircle = np.sin(tcircle)*0.8
ax.plot(xcircle, ycircle, color='black')
